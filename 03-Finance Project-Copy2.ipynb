# %%
import pandas as pd
import pandas_datareader.data as web
import numpy as np 
import yfinance as yf
import datetime as datetime
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2020,1,1)
bac = yf.download('BAC', start,end)
jpm = yf.download('JPM', start,end)
c = yf.download('C', start,end)
gs = yf.download('GS', start,end)
ms = yf.download('MS', start,end)
wfc = yf.download('WFC', start,end)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
stocks = pd.concat([bac, c, gs, jpm, ms, wfc], axis=1)

# %%
returns = pd.DataFrame()

# %%
ticket = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']
returns[ticket] = stocks['Close'].pct_change()
returns.head()
# Out:
#                  BAC         C        GS       JPM        MS       WFC
# Date
# 2006-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2006-01-04 -0.010620 -0.018462 -0.013813 -0.005772  0.000686 -0.011599
# 2006-01-05  0.001289  0.004960 -0.000393  0.003029  0.002742 -0.001110
# 2006-01-06 -0.001501  0.000000  0.014169  0.007046  0.001025  0.005874
# 2006-01-09  0.000644 -0.004730  0.012030  0.016241  0.010586 -0.000158

# %%
sns.pairplot(returns)
plt.show()

# %%
# 2008 Financial crisis- Government bail out of Citibank and Bank of America to save the most important financial institution of the world.  
returns.idxmax()
# Out:
# BAC   2009-04-09
# C     2008-11-24
# GS    2008-11-24
# JPM   2009-01-21
# MS    2008-10-13
# WFC   2008-07-16
# dtype: datetime64[ns]

# %%
# Financial crisis of 2007-2008
returns.reset_index(inplace=True)
returns.idxmin()
# Out:
# Date      0
# BAC     766
# C       793
# GS      766
# JPM     766
# MS      697
# WFC     766
# dtype: int64

# %%
returns.std()
# Out:
# Date    1475 days 20:17:52.609428720
# BAC                         0.032169
# C                            0.03375
# GS                          0.022944
# JPM                         0.024404
# MS                          0.033092
# WFC                         0.026512
# dtype: object

# %%
returns['Date'] = pd.to_datetime(returns['Date'])

# %%
returns_2015_ms = returns[returns['Date'].dt.year == 2015]['MS']

# %%
# Distplot of Mogney Stanley bank 
sns.displot(returns_2015_ms, bins = 40, kde = True, color = 'Green')

# %%
returns_2008_c = returns[returns['Date'].dt.year == 2008]['C']
returns_2008_bac = returns[returns['Date'].dt.year == 2008]['BAC']
returns_2008_gs = returns[returns['Date'].dt.year == 2008]['GS']
returns_2008_ms = returns[returns['Date'].dt.year == 2008]['MS']

# %%
# Distplot of Citibank 

sns.displot(returns_2008_c, kde=True, bins = 30)
plt.show()

# %%
sns.displot(returns_2008_bac, kde=True, bins = 30)
plt.show()

# %%
sns.displot(returns_2008_gs, kde=True, bins = 30)
plt.show()

# %%
sns.displot(returns_2008_gs, kde=True, bins = 30)
plt.show()

# %%
sns.displot(returns_2008_ms, kde=True, bins = 30)
plt.show()

# %%
plt.figure(figsize = (12,5))
sns.lineplot(stocks['Close'], palette='Set1')
# Out:
# <Axes: xlabel='Date'>

# %%
new_stocks = stocks.reset_index()

# %%
plt.figure(figsize= (12,5))
